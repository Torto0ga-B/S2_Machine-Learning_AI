# %%
#Imports and loads data
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Telco_Cusomer_Churn.csv')

df.head()

# %%
df.shape #Basic structure
# Out:
# (7043, 21)

# %%
df.dtypes # Data Types

# %%
df['Churn']. value_counts(normalize=True) # Churn Distribution

# %%
df.isnull().sum() #Missing Values

# %%
df.describe(include='all').T # Descriptive stats

# %%
#Fix totalcharges 
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df.isnull().sum()

# %%
df.to_csv('../data/cleaned_Telco.csv', index=False) #Safe cleaned version for pipleine consistency

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Converts the blank spaces to NaN

# %% [markdown]
# This was the result of running the fully functional code
#
# Train: (4930, 20) Val: (1056, 20) Test: (1057, 20)
# best RF Params {'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 300}
# ===== Logistic Regression =====
# Accuracy: 0.7395833333333334
# Precision: 0.5055432372505543
# Recall: 0.8142857142857143
# F1: 0.6238030095759234
# ROC-AUC: 0.8447740243004418
# ===== Random Forest (Tuned) =====
# Accuracy: 0.7320075757575758
# Precision: 0.4967462039045553
# Recall: 0.8178571428571428
# F1: 0.6180836707152496
# ROC-AUC: 0.8442539580265096
# Selected Model: Logistic Regression
# =====FINAL TEST PERFORMANCE=====
# ===== Final Model =====
# Accuracy: 0.7483443708609272
# Precision: 0.5177304964539007
# Recall: 0.7793594306049823
# F1: 0.6221590909090909
# ROC-AUC: 0.8447142018564038
# Models saved successfully
