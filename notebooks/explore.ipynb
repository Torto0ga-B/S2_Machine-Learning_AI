# %%
#Imports and loads data
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Telco_Cusomer_Churn.csv')

df.head()

# %%
df.shape #Basic structure
# Out:
# (7043, 21)

# %%
df.dtypes # Data Types

# %%
df['Churn']. value_counts(normalize=True) # Churn Distribution

# %%
df.isnull().sum() #Missing Values

# %%
df.describe(include='all').T # Descriptive stats

# %%
#Fix totalcharges 
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df.isnull().sum()

# %%
df.to_csv('../data/cleaned_Telco.csv', index=False) #Safe cleaned version for pipleine consistency

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Converts the blank spaces to NaN
